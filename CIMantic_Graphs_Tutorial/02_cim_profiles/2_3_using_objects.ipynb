# %% [markdown]
# ```mermaid
# classDiagram
#     class Identity{
#         + identifier: uuid
#         # \_\_uuid\_\_: class UUID_Meta
#         # \_\_json_ld\_\_: str~repr~
#
#         + pprint()
#         + uri() str~UUID~
#         ~ uuid(mRID,name,str)
#
#         # \_\_repr\_\_() str~JSON-LD~
#         # \_\_dict\_\_() dict
#         # \_\_str\_\_() str~dict~
#
#
#
#     }
#
# ```
