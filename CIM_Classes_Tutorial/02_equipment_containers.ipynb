# %% [markdown]
# # Equipment & Equipment Containers

# %% [markdown]
# All diagrams within this page have been auto-generated using mermaid.js and the `cimgraph.utils` module of CIMantic Graphs, which can be imported as

# %%
from cimgraph import utils
from mermaid import Mermaid
import cimgraph.data_profile.cim17v40 as cim

# %% [markdown]
# ## Equipment Containers

# %% [markdown]
# For the purposes of naming, asset management, and network modeling, all nodes and equipment are associated with a container class. Each node will have a container as specified by the `ConnectivityNode.ConnectivityNodeContainer` association, while equipment will have a primary container specified by `Equipment.EquipmentContainer`.
#
# The relationships between nodes, equipment, and container classes are illustrated below:

# %%
diagram_text = utils.get_mermaid([
    cim.ConnectivityNodeContainer, # Top-level container class
    cim.ConnectivityNode, # Electrical bus / node
    cim.Equipment, # Any equipment
    cim.EquipmentContainer # Container of equipment
], show_attributes=False)
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-362f390b-5c24-4860-bb80-114d42e6d1fd"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class ConnectivityNodeContainer{\n    }\n    ConnectivityNodeContainer --> "0..*" ConnectivityNode : ConnectivityNodes \n    class ConnectivityNode{\n    }\n    ConnectivityNode --> "0..1" ConnectivityNodeContainer : ConnectivityNodeContainer \n    class Equipment{\n    }\n    Equipment --> "0..*" EquipmentContainer : AdditionalEquipmentContainer \n    Equipment --> "0..1" EquipmentContainer : EquipmentContainer \n    class EquipmentContainer{\n    }\n    EquipmentContainer --> "0..*" Equipment : AdditionalGroupedEquipment \n    EquipmentContainer --o "0..*" Equipment : Equipments \n    ConnectivityNodeContainer <|-- EquipmentContainer : inherits from\n';
#             const element = document.querySelector('.mermaid-362f390b-5c24-4860-bb80-114d42e6d1fd');
#             const { svg } = await mermaid.render('graphDiv-362f390b-5c24-4860-bb80-114d42e6d1fd', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ### Substation and Feeders
#
# The `Substation` and `Feeder` classes are used to describe containment and naming of equipment within substations and distribution feeders. For most applications, each feeder is described as having a single normal energizing substation that serves as the source for all downstream customers.

# %%
diagram_text = utils.get_mermaid_path(cim.Substation,'NormalEnergizedFeeder')
diagram_text = utils.add_mermaid_path(cim.Feeder, 'NormalEnergizingSubstation', diagram_text)
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-5b899d28-3a8a-44ff-8676-afd447869b4a"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class Substation{\n    }\n    Substation --o "0..*" Feeder : NormalEnergizedFeeder \n    class Feeder{\n    }\n    Feeder --> "0..1" Substation : NormalEnergizingSubstation \n    class Substation{\n    }\n';
#             const element = document.querySelector('.mermaid-5b899d28-3a8a-44ff-8676-afd447869b4a');
#             const { svg } = await mermaid.render('graphDiv-5b899d28-3a8a-44ff-8676-afd447869b4a', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ### Substation Bays and Voltage Levels
#
# In describing large substations with node-breaker models, it is common to define equipment containment based on the physical bay and voltage level such that all conducting equipment, protection relays, measurements, and telemetry are grouped together. The associations between the `Substation`, `Bay`, and `VoltageLevel` classes are illustrated below. The configuration of a particular bay (ring bus, main-and-transfer, etc.) can be specified using the `BreakerConfiguration` and `BusBarConfiguration` enumerations.

# %%
diagram_text = utils.get_mermaid([
    cim.Substation,
    cim.VoltageLevel,
    cim.Bay
], show_attributes=True)
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-90b0468b-24a4-41a0-9cb5-9001f94e0f09"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class Substation{\n    }\n    Substation --o "0..*" Bay : Bays \n    Substation --o "0..*" VoltageLevel : VoltageLevels \n    class VoltageLevel{\n        + highVoltageLimit: float | Voltage\n        + lowVoltageLimit: float | Voltage\n    }\n    VoltageLevel --o "0..*" Bay : Bays \n    VoltageLevel --> "0..1" Substation : Substation \n    class Bay{\n        + bayEnergyMeasFlag: bool\n        + bayPowerMeasFlag: bool\n        + breakerConfiguration: enum:BreakerConfiguration\n        + busBarConfiguration: enum:BusbarConfiguration\n    }\n    Bay --> "0..1" Substation : Substation \n    Bay --> "0..1" VoltageLevel : VoltageLevel \n';
#             const element = document.querySelector('.mermaid-90b0468b-24a4-41a0-9cb5-9001f94e0f09');
#             const { svg } = await mermaid.render('graphDiv-90b0468b-24a4-41a0-9cb5-9001f94e0f09', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# It is possible to associate equipment with multiple containers using the `Equipment.AdditionalEquipmentContainer` association. For example, a breaker that is contained within a particular substation bay would be expressed as:

# %%
breaker = cim.Breaker(EquipmentContainer=cim.Bay())
breaker.AdditionalEquipmentContainer.append(cim.Substation())
breaker.pprint()
# Out:
# {
#     "@id": "54aad8e6-68fc-402b-baa3-b164dd2558c4",
#     "@type": "Breaker",
#     "AdditionalEquipmentContainer": [
#         {
#             "@id": "75ffb6c7-94a2-4e8e-ad38-20375cae2eb9",
#             "@type": "Substation"
#         }
#     ],
#     "EquipmentContainer": {
#         "@id": "b1a3bad0-32ab-4d09-888f-1102d2599ef4",
#         "@type": "Bay"
#     }
# }

# %% [markdown]
# ## PowerSystemResource

# %%
root = [
    # cim.EquipmentContainer, # Container of equipment
    cim.Substation,
    cim.VoltageLevel,
    cim.Bay,
    cim.BreakerConfiguration
]
set(map(type, root))
# Out:
# {enum.EnumMeta, type}

# %% [markdown]
# All elements of the power system model are categorized as a `PowerSystemResource`, which can be any item of equipment (e.g. a switch), an equipment container with multiple pieces of equipment (e.g. a substation or a feeder), or an organizational entity (e.g. a control area). All power systems modeling components are then divided into two categories, depending on whether the particular focus is on the electrical connectivity or the physical assets.  All electrical aspects of equipment are associated with the classes inheriting from `Equipment` class in the Grid (formerly 61970) package.  The physical aspects of equipment are associated with the child classes of `Asset` and `AssetInfo` from the Enterprise (formerly 61968) package.

# %%
diagram_text = utils.get_mermaid([
    # cim.IdentifiedObject,
    cim.Asset,
    cim.AssetInfo,
    cim.PowerSystemResource,
    cim.Equipment,
    cim.ConductingEquipment
], show_attributes=False)
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-dd640b22-2c13-4c4f-ac30-868fb3f45f8c"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class Asset{\n    }\n    Asset --> "0..1" AssetInfo : AssetInfo \n    Asset --> "0..*" PowerSystemResource : PowerSystemResources \n    class AssetInfo{\n    }\n    AssetInfo --> "0..*" Asset : Assets \n    AssetInfo --> "0..*" PowerSystemResource : PowerSystemResources \n    class PowerSystemResource{\n    }\n    PowerSystemResource --> "0..1" AssetInfo : AssetDatasheet \n    PowerSystemResource --> "0..*" Asset : Assets \n    class Equipment{\n    }\n    PowerSystemResource <|-- Equipment : inherits from\n    class ConductingEquipment{\n    }\n    Equipment <|-- ConductingEquipment : inherits from\n';
#             const element = document.querySelector('.mermaid-dd640b22-2c13-4c4f-ac30-868fb3f45f8c');
#             const { svg } = await mermaid.render('graphDiv-dd640b22-2c13-4c4f-ac30-868fb3f45f8c', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %%
diagram_text = utils.get_mermaid([
    cim.ConductingEquipment, # Anything that conducts electricity
    cim.Switch, # All types of switches
    cim.Conductor, # Abstract conductor
    cim.ACLineSegment, # Overhead lines & underground cables
    cim.PowerTransformer, # Transformers
    cim.EnergyConnection, # Abstract class for shunt elements
    cim.EnergyConsumer, # Loads
    cim.RegulatingCondEq, # Abstract class
    cim.RotatingMachine, # Generators and motors
    cim.PowerElectronicsConnection, # Inverters
    cim.ShuntCompensator, # Capacitors & reactors
    cim.EnergySource # Slack bus / infinite source
    ], show_attributes=False)
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-f628cea5-c700-46d4-9980-3276e56fa151"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class ConductingEquipment{\n    }\n    class Switch{\n    }\n    ConductingEquipment <|-- Switch : inherits from\n    class Conductor{\n    }\n    ConductingEquipment <|-- Conductor : inherits from\n    class ACLineSegment{\n    }\n    Conductor <|-- ACLineSegment : inherits from\n    class PowerTransformer{\n    }\n    ConductingEquipment <|-- PowerTransformer : inherits from\n    class EnergyConnection{\n    }\n    ConductingEquipment <|-- EnergyConnection : inherits from\n    class EnergyConsumer{\n    }\n    EnergyConnection <|-- EnergyConsumer : inherits from\n    class RegulatingCondEq{\n    }\n    EnergyConnection <|-- RegulatingCondEq : inherits from\n    class RotatingMachine{\n    }\n    RegulatingCondEq <|-- RotatingMachine : inherits from\n    class PowerElectronicsConnection{\n    }\n    RegulatingCondEq <|-- PowerElectronicsConnection : inherits from\n    class ShuntCompensator{\n    }\n    RegulatingCondEq <|-- ShuntCompensator : inherits from\n    class EnergySource{\n    }\n    EnergyConnection <|-- EnergySource : inherits from\n';
#             const element = document.querySelector('.mermaid-f628cea5-c700-46d4-9980-3276e56fa151');
#             const { svg } = await mermaid.render('graphDiv-f628cea5-c700-46d4-9980-3276e56fa151', graphDefinition);
#             element.innerHTML = svg;
#         </script>
