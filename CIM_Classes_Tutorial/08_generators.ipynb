# %% [markdown]
# # Generator Modeling

# %% [markdown]
# Representation of conventional generators in CIM is divided into three packages across the 61970 information model. The set of classes in the Wires package contains the electrical representation of units for use in basic power flow studies and modeling. The set of classes in the Generation package contains prime mover information for use in a dispatcher training simulator and power applications, such as economic dispatch. Finally, the set of classes in the Dynamics package is used for transient stability and electromechanical simulations.

# %% [markdown]
# ## Synchronous and Asynchronous Machines

# %% [markdown]
# ----

# %% [markdown]
# The two primary classes used for representation of generators for use in power flow studies and modeling of the electrical network are SynchronousMachine and AsynchronousMachine. All conventional thermal, hydro, and other synchronously-connected (i.e. rotating at an even multiple of 50Hz or 60Hz) is represented using the SynchronousMachine class. This class is also used for large motor loads connected through synchronous motors. Induction motors and Type I / Type II wind turbines are represented by the AsynchronousMachine class. The operating modes and usage are specified as enumerations, rather than as separate classes, as shown in Figure below.

# %%
import os
from cimgraph import utils
from mermaid import Mermaid
import cimgraph.data_profile.cim17v40 as cim
os.environ['CIMG_CIM_PROFILE'] = 'cim17v40'

# %%
diagram_text = utils.get_mermaid([cim.PowerSystemResource, cim.Equipment, cim.ConductingEquipment, cim.EnergyConnection,
                                  cim.RegulatingCondEq, cim.RotatingMachine, cim.SynchronousMachine, cim.AsynchronousMachine,
                                  cim.SynchronousMachineKind, cim.SynchronousMachineOperatingMode, cim.AsynchronousMachineKind])
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-8d3b9f08-126f-409b-a579-f0e5b627cbee"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class PowerSystemResource{\n    }\n    class Equipment{\n        + aggregate: bool\n        + inService: bool\n        + networkAnalysisEnabled: bool\n        + normallyInService: bool\n    }\n    PowerSystemResource <|-- Equipment : inherits from\n    class ConductingEquipment{\n    }\n    Equipment <|-- ConductingEquipment : inherits from\n    class EnergyConnection{\n    }\n    ConductingEquipment <|-- EnergyConnection : inherits from\n    class RegulatingCondEq{\n        + controlEnabled: bool\n    }\n    EnergyConnection <|-- RegulatingCondEq : inherits from\n    class RotatingMachine{\n        + ratedPowerFactor: float\n        + p: float | ActivePower\n        + q: float | ReactivePower\n        + ratedS: float | ApparentPower\n        + ratedU: float | Voltage\n    }\n    RegulatingCondEq <|-- RotatingMachine : inherits from\n    class SynchronousMachine{\n        + coolantCondition: float\n        + earthing: bool\n        + mu: float\n        + referencePriority: int\n        + aVRToManualLag: float | Seconds\n        + aVRToManualLead: float | Seconds\n        + baseQ: float | ReactivePower\n        + condenserP: float | ActivePower\n        + coolantType: enum:CoolantType\n        + earthingStarPointR: float | Resistance\n        + earthingStarPointX: float | Reactance\n        + ikk: float | CurrentFlow\n        + manualToAVR: float | Seconds\n        + maxQ: float | ReactivePower\n        + maxU: float | Voltage\n        + minQ: float | ReactivePower\n        + minU: float | Voltage\n        + operatingMode: enum:SynchronousMachineOperatingMode\n        + qPercent: float | PerCent\n        + r: float | Resistance\n        + r0: float | Resistance\n        + r2: float | Resistance\n        + satDirectSubtransX: float | PU\n        + satDirectSyncX: float | PU\n        + satDirectTransX: float | PU\n        + shortCircuitRotorType: enum:ShortCircuitRotorKind\n        + type: enum:SynchronousMachineKind\n        + voltageRegulationRange: float | PerCent\n        + x0: float | Reactance\n        + x2: float | Reactance\n    }\n    RotatingMachine <|-- SynchronousMachine : inherits from\n    class AsynchronousMachine{\n        + converterFedDrive: bool\n        + iaIrRatio: float\n        + polePairNumber: int\n        + reversible: bool\n        + rxLockedRotorRatio: float\n        + asynchronousMachineType: enum:AsynchronousMachineKind\n        + efficiency: float | PerCent\n        + nominalFrequency: float | Frequency\n        + nominalSpeed: float | RotationSpeed\n        + ratedMechanicalPower: float | ActivePower\n        + rr1: float | Resistance\n        + rr2: float | Resistance\n        + tpo: float | Seconds\n        + tppo: float | Seconds\n        + xlr1: float | Reactance\n        + xlr2: float | Reactance\n        + xm: float | Reactance\n        + xp: float | Reactance\n        + xpp: float | Reactance\n        + xs: float | Reactance\n    }\n    RotatingMachine <|-- AsynchronousMachine : inherits from\n    class SynchronousMachineKind:::enum {\n        condenser\n        generator\n        generatorOrCondenser\n        generatorOrCondenserOrMotor\n        generatorOrMotor\n        motor\n        motorOrCondenser\n}\n    class SynchronousMachineOperatingMode:::enum {\n        condenser\n        generator\n        motor\n}\n    class AsynchronousMachineKind:::enum {\n        generator\n        motor\n}\n';
#             const element = document.querySelector('.mermaid-8d3b9f08-126f-409b-a579-f0e5b627cbee');
#             const { svg } = await mermaid.render('graphDiv-8d3b9f08-126f-409b-a579-f0e5b627cbee', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ## Production Cost Modeling

# %% [markdown]
# Detailed production cost models for economic dispatch, unit commitment, and other optimization studies are included in the 61970 Production package. These classes are separate from the electrical parameters defined in the Wires package and Dynamics package. The Production classes contain detailed parameters needed for specifying heat curves, ramp rates, startup/shutdown times, etc. A high-level summary is provided in Figure below. The package also contains detailed models of plant component time curves (not shown) for timeseries optimization.

# %%
diagram_text = utils.get_mermaid([cim.Equipment, cim.GeneratingUnit, cim.ThermalGeneratingUnit, cim.WindGeneratingUnit,
                                  cim.RotatingMachine, cim.GenUnitOpSchedule])
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-ecdb73a9-19e2-435e-a5b3-bc2a3a6b56e2"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class Equipment{\n        + aggregate: bool\n        + inService: bool\n        + networkAnalysisEnabled: bool\n        + normallyInService: bool\n    }\n    class GeneratingUnit{\n        + longPF: float\n        + normalPF: float\n        + penaltyFactor: float\n        + shortPF: float\n        + tieLinePF: float\n        + allocSpinResP: float | ActivePower\n        + autoCntrlMarginP: float | ActivePower\n        + baseP: float | ActivePower\n        + controlDeadband: float | ActivePower\n        + controlPulseHigh: float | Seconds\n        + controlPulseLow: float | Seconds\n        + controlResponseRate: float | ActivePowerChangeRate\n        + efficiency: float | PerCent\n        + genControlMode: enum:GeneratorControlMode\n        + genControlSource: enum:GeneratorControlSource\n        + governorMPL: float | PU\n        + governorSCD: float | PerCent\n        + highControlLimit: float | ActivePower\n        + initialP: float | ActivePower\n        + lowControlLimit: float | ActivePower\n        + lowerRampRate: float | ActivePowerChangeRate\n        + maxEconomicP: float | ActivePower\n        + maximumAllowableSpinningReserve: float | ActivePower\n        + maxOperatingP: float | ActivePower\n        + minEconomicP: float | ActivePower\n        + minimumOffTime: float | Seconds\n        + minOperatingP: float | ActivePower\n        + modelDetail: int | Classification\n        + nominalP: float | ActivePower\n        + raiseRampRate: float | ActivePowerChangeRate\n        + ratedGrossMaxP: float | ActivePower\n        + ratedGrossMinP: float | ActivePower\n        + ratedNetMaxP: float | ActivePower\n        + startupCost: Money\n        + startupTime: float | Seconds\n        + totalEfficiency: float | PerCent\n        + variableCost: Money\n    }\n    GeneratingUnit --o "0..1" GenUnitOpSchedule : GenUnitOpSchedule \n    GeneratingUnit --> "0..*" RotatingMachine : RotatingMachine \n    Equipment <|-- GeneratingUnit : inherits from\n    class ThermalGeneratingUnit{\n        + oMCost: float | CostPerHeatUnit\n    }\n    GeneratingUnit <|-- ThermalGeneratingUnit : inherits from\n    class WindGeneratingUnit{\n        + windGenUnitType: enum:WindGenUnitKind\n    }\n    GeneratingUnit <|-- WindGeneratingUnit : inherits from\n    class RotatingMachine{\n        + ratedPowerFactor: float\n        + p: float | ActivePower\n        + q: float | ReactivePower\n        + ratedS: float | ApparentPower\n        + ratedU: float | Voltage\n    }\n    RotatingMachine --> "0..1" GeneratingUnit : GeneratingUnit \n    class GenUnitOpSchedule{\n    }\n    GenUnitOpSchedule --> "0..1" GeneratingUnit : GeneratingUnit \n';
#             const element = document.querySelector('.mermaid-ecdb73a9-19e2-435e-a5b3-bc2a3a6b56e2');
#             const { svg } = await mermaid.render('graphDiv-ecdb73a9-19e2-435e-a5b3-bc2a3a6b56e2', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ## Long-Term Dynamics Modeling

# %% [markdown]
# Timeseries power system simulation can be divided into three categories. The first is quasistatic power flows solutions. These methods solve a single static snapshot at each timestep. No modeling of generator governor dynamics is needed. The only required CIM classes are `SynchronousMachine` and `AsynchronousMachine`. The second is long-term dynamics solutions, which are used by operator training simulators / dispatcher training simulators and implement basic models of the generator prime mover (i.e. turbine) and governor used for primary and secondary frequency control. These solvers typically solve a power flow solution every one second and use a timeseries integration of governor response to determine frequency, interchange, and area control error (ACE). These simulations require the governor models found in the GenerationTrainingSimulation package described here. The third is transient stability and other full dynamic solutions, which require detailed models of the generator inertia, governors, excitation, stabilizers, etc. (which are described in Section 11.4).
#
# The GenerationTrainingSimulation package contains detailed models inheriting from `PrimeMover` to describe the basic long-term response of different kinds of generation. Each of the classes shown in Figure below contain detailed prime mover models and key modeling parameters (such as HydroTurbine.waterStartingTime) needed to tune large power system models for use in an operator training simulator.

# %%
diagram_text = utils.get_mermaid([cim.PrimeMover, cim.HydroTurbine, cim.SteamTurbine, cim.CombustionTurbine])
Mermaid(diagram_text)
# Out:
#         <div class="mermaid-8c0747af-7e76-4171-945c-b66f71d5e13c"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class PrimeMover{\n        + primeMoverRating: float\n    }\n    class HydroTurbine{\n        + gateRateLimit: float\n        + gateUpperLimit: float | PU\n        + maxHeadMaxP: float | ActivePower\n        + minHeadMaxP: float | ActivePower\n        + speedRating: float | RotationSpeed\n        + speedRegulation: float | PU\n        + transientDroopTime: float | Seconds\n        + transientRegulation: float | PU\n        + turbineRating: float | ActivePower\n        + turbineType: enum:HydroTurbineKind\n        + waterStartingTime: float | Seconds\n    }\n    PrimeMover <|-- HydroTurbine : inherits from\n    class SteamTurbine{\n        + shaft1PowerHP: float\n        + shaft1PowerIP: float\n        + shaft1PowerLP1: float\n        + shaft1PowerLP2: float\n        + shaft2PowerHP: float\n        + shaft2PowerIP: float\n        + shaft2PowerLP1: float\n        + shaft2PowerLP2: float\n        + crossoverTC: float | Seconds\n        + reheater1TC: float | Seconds\n        + reheater2TC: float | Seconds\n        + steamChestTC: float | Seconds\n    }\n    PrimeMover <|-- SteamTurbine : inherits from\n    class CombustionTurbine{\n        + heatRecoveryFlag: bool\n        + ambientTemp: float | Temperature\n        + auxPowerVersusFrequency: float | PU\n        + auxPowerVersusVoltage: float | PU\n        + capabilityVersusFrequency: float | PU\n        + powerVariationByTemp: float | PU\n        + referenceTemp: float | Temperature\n        + timeConstant: float | Seconds\n    }\n    PrimeMover <|-- CombustionTurbine : inherits from\n';
#             const element = document.querySelector('.mermaid-8c0747af-7e76-4171-945c-b66f71d5e13c');
#             const { svg } = await mermaid.render('graphDiv-8c0747af-7e76-4171-945c-b66f71d5e13c', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ## Transient Stability and Dynamics Modeling

# %% [markdown]
# CIM provides an extremely detailed set of packages for power system dynamics modeling covering dynamic models of synchronous/asynchronous machines, generator governors, power system stabilizers, high-voltage direct current (HVDC) resources, static VAr compensators, voltage control systems, and composite load models. The package also contains several dozen classes for all standard generation and wind turbine model representations used in industry and found within the literature. Description of the classes and attributes used for dynamic modeling is beyond the scope of this tutorial.
